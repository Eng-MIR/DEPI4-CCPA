# %% [markdown]
# ##**10. Saving Folders and Generated Files to Github**

# %% [markdown]
# ###**10.1 Clone the Repository**

# %%
# !git clone https://secret@github.com/Eng-MIR/DEPI4-CCPA.git
# Out:
# Cloning into 'DEPI4-CCPA'...
# remote: Enumerating objects: 638, done.
# remote: Counting objects: 100% (192/192), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 638 (delta 118), reused 135 (delta 84), pack-reused 446 (from 1)
# Receiving objects: 100% (638/638), 11.30 MiB | 18.29 MiB/s, done.
# Resolving deltas: 100% (205/205), done.

# %% [markdown]
# ###**10.2 Copy Files/Folders**

# %%
# Move a single file
#!cp /content/my_file.txt /content/<REPO_NAME>/

# Move an entire folder
# !cp -r /content/Models /content/DEPI4-CCPA/
# !cp -r /content/mlruns /content/DEPI4-CCPA/

# %% [markdown]
# ###**10.3 Commit and Push**

# %%
# %cd /content/DEPI4-CCPA
# !git config --global user.email "eng_mir@hotmail.com"
# !git config --global user.name "Eng-MIR"
# !git add .
# !git commit -m "Added folder and files from Colab"
# !git push origin main
# Out:
# /content/DEPI4-CCPA
# [main 573f7e2] Added folder and files from Colab
#  66 files changed, 228 insertions(+), 2 deletions(-)
#  rewrite Models/customer_churn_xgb_model.pkl (66%)
#  create mode 100644 mlruns/503888609355123195/095ebd78c46548c7afafbb2fea903843/meta.yaml
#  create mode 100644 mlruns/503888609355123195/095ebd78c46548c7afafbb2fea903843/metrics/accuracy
#  create mode 100644 mlruns/503888609355123195/095ebd78c46548c7afafbb2fea903843/metrics/f1_score
#  create mode 100644 mlruns/503888609355123195/095ebd78c46548c7afafbb2fea903843/metrics/precision
#  create mode 100644 mlruns/503888609355123195/095ebd78c46548c7afafbb2fea903843/metrics/recall
#  create mode 100644 mlruns/503888609355123195/095ebd78c46548c7afafbb2fea903843/metrics/roc_auc
#  create mode 100644 mlruns/503888609355123195/095ebd78c46548c7afafbb2fea903843/outputs/m-2cae42fd551b459d99ba61e9307fdba1/meta.yaml
#  create mode 100644 mlruns/503888609355123195/095ebd78c46548c7afafbb2fea903843/params/max_depth
# ...

# %%
# !git push origin main
# Out:
# Everything up-to-date
